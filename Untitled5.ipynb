# %% [markdown]
# <a href="https://colab.research.google.com/github/Milton1972/Dio-Java-B-sico/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Conectar ao banco de dados (ou criar se não existir)
conexão = sqlite3.connect('dados_vendas.db')

# Criar um cursor
cursor = conexão.cursor()

# Criar tabela (se não existir)
cursor.execute('''
CREATE TABLE IF NOT EXISTS vendas1(
  id_venda INTEGER PRIMARY KEY AUTOINCREMENT,
  data_venda DATE,
  produto TEXT,
  categoria TEXT,
  valor_venda REAL
)
''')

# inserir alguns dados
cursor.execute('''
INSERT INTO vendas1 (data_venda, produto, categoria, valor_venda)VALUES
('2023-01-01', 'Produto A', 'Eletrônicos', 1500.00),
('2023-01-05', 'Produto B', 'Roupas', 350.00),
('2023-02-10', 'Produto C', 'Eletrônicos', 1200.00),
('2023-03-15', 'Produto D', 'Livros', 200.00),
('2023-03-20', 'Produto E', 'Eletrônicos', 800.00),
('2023-04-02', 'Produto F', 'Roupas', 400.00),
('2023-05-05', 'Produto G', 'Livros', 150.00),
('2023-06-10', 'Produto H', 'Eletrônicos', 1000.00),
('2023-07-20', 'Produto I', 'Roupas', 600.00),
('2023-08-25', 'Produto J', 'Eletrônicos', 700.00),
('2023-09-30', 'Produto K', 'Livros', 300.00),
('2023-10-05', 'Produto L', 'Roupas', 450.00),
('2023-11-15', 'Produto M', 'Eletrônicos', 900.00),
('2023-12-20', 'Produto N', 'Livros', 250.00)
''')

# Confirmar as mudanças
conexão.commit()

# Ler os dados da tabela para um DataFrame
df_vendas = pd.read_sql_query("SELECT * FROM vendas1", conexão)

# Calcular média mensal de vendas
df_vendas['mes_ano'] = pd.to_datetime(df_vendas['data_venda']).dt.to_period('M')
media_mensal = df_vendas.groupby('mes_ano')['valor_venda'].mean().reset_index()

# Converter a coluna 'mes_ano' para string
media_mensal['mes_ano'] = media_mensal['mes_ano'].astype(str)

# Gráfico da linha média de vendas
plt.figure(figsize=(10, 6))
sns.lineplot(data=media_mensal, x='mes_ano', y= 'valor_venda', marker='o')
plt.title('Media de vendas Mensais')
plt.xlabel('Mes-Ano')
plt.ylabel('Valor Medio da Venda')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# Histograma de vendas

plt.figure(figsize=(10, 6))
sns.histplot(df_vendas['valor_venda'], bins=20, kde=True)
plt.title('Distribuição de Vendas')
plt.xlabel('Valor da Venda')
plt.ylabel('Frequencia')
plt.grid(True)
plt.show()

# Boxplot das vendas por mês

plt.figure(figsize=(12, 6))
sns.boxplot(x='mes_ano', y='valor_venda', data=df_vendas)
plt.title('Boxplot de vendas por mês')
plt.xlabel('Mês-Ano')
plt.ylabel('Valor de Venda')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Conectar ao banco de dados (ou criar se não existir)
conexão = sqlite3.connect('dados_vendas.db')

# Criar um cursor
cursor = conexão.cursor()

# Criar tabela (se não existir)
cursor.execute('''
CREATE TABLE IF NOT EXISTS vendas1(
  id_venda INTEGER PRIMARY KEY AUTOINCREMENT,
  data_venda DATE,
  produto TEXT,
  categoria TEXT,
  valor_venda REAL
)
''')

# inserir alguns dados
cursor.execute('''
INSERT INTO vendas1 (data_venda, produto, categoria, valor_venda)VALUES
('2023-01-01', 'Produto A', 'Eletrônicos', 1500.00),
('2023-01-05', 'Produto B', 'Roupas', 350.00),
('2023-02-10', 'Produto C', 'Eletrônicos', 1200.00),
('2023-03-15', 'Produto D', 'Livros', 200.00),
('2023-03-20', 'Produto E', 'Eletrônicos', 800.00),
('2023-04-02', 'Produto F', 'Roupas', 400.00),
('2023-05-05', 'Produto G', 'Livros', 150.00),
('2023-06-10', 'Produto H', 'Eletrônicos', 1000.00),
('2023-07-20', 'Produto I', 'Roupas', 600.00),
('2023-08-25', 'Produto J', 'Eletrônicos', 700.00),
('2023-09-30', 'Produto K', 'Livros', 300.00),
('2023-10-05', 'Produto L', 'Roupas', 450.00),
('2023-11-15', 'Produto M', 'Eletrônicos', 900.00),
('2023-12-20', 'Produto N', 'Livros', 250.00)
''')
# Confirmar as mudanças
conexão.commit()

# Carregar

# %% [markdown]
# O código executado faz um excelente trabalho ao conectar ao banco de dados SQLite, carregar os dados de vendas, e realizar uma análise básica para identificar padrões e gerar insights.
#
# Conclusão
#
# No geral, o código fornece uma base sólida para analisar dados de vendas e identificar padrões significativos. Com algumas melhorias pode tornar-se uma ferramenta ainda mais poderosa para suporte à tomada de decisão.
#
# Milton Cesar Sandes
# Engenharia de Software
# 2024118498
